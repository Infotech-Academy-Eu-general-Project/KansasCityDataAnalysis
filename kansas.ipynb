# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv) 
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#pip install sodapy

# %%
#pip install dnspython

# %%
#pip install pymongo

# %%
#pip install pymongo[srv]

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.kcmo.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.kcmo.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
#result_1 = client.get("dmjw-d28i", limit=200000)
#result_2 = client.get("pxaa-ahcm", limit=200000)
#result_3 = client.get("vsgj-uufz", limit=200000)
#result_4 = client.get("w795-ffu6", limit=200000)
#result_5 = client.get("x39y-7d3m", limit=200000)


# Convert to pandas DataFrame
#results_df_2018 = pd.DataFrame.from_records(result_1)
#results_df_2019 = pd.DataFrame.from_records(result_2)
#results_df_2020 = pd.DataFrame.from_records(result_3)
#results_df_2021 = pd.DataFrame.from_records(result_4)
#results_df_2022 = pd.DataFrame.from_records(result_5)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#results_df_2018=results_df_2018.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
#results_df_2019=results_df_2019.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
#results_df_2020=results_df_2020.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
#results_df_2021=results_df_2021.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
#results_df_2022=results_df_2022.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})

# %%
import pymongo
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
import numpy as np

# %% [markdown]
# # USERNAME,PASSWORD FOR MONGO DB

# %%
client = pymongo.MongoClient("mongodb+srv://infotech_emre:O6iAdFUUJb764Wv1@cluster0.2kfd1pw.mongodb.net/?retryWrites=true&w=majority", server_api=ServerApi('1'))
db=client.get_database('Kansas')

# %%
#db["crime_record_2018"].insert_many(results_df_2018.to_dict('records'))
#db["crime_record_2019"].insert_many(results_df_2019.to_dict('records'))
#db["crime_record_2020"].insert_many(results_df_2020.to_dict('records'))
#db["crime_record_2021"].insert_many(results_df_2021.to_dict('records'))
#db["crime_record_2022"].insert_many(results_df_2022.to_dict('records'))

# %%
satir_sayisi_bilgi=db.crime_record_2018
satir_sayisi_bilgi.count_documents({})
# Out:
# 128938

# %% [markdown]
# # DICTIONARY FROM MONGO DB TO DF

# %%
from pymongo import MongoClient
db = client.get_database('Kansas')
#########################################
collection_2018 = db["crime_record_2018"]
data = collection_2018.find()
df_18=pd.DataFrame.from_dict(data)

# %%
collection_2019 = db["crime_record_2019"]
data = collection_2019.find()
df_19=pd.DataFrame.from_dict(data)

# %%
collection_2020 = db["crime_record_2020"]
data = collection_2020.find()
df_20=pd.DataFrame.from_dict(data)

# %%
collection_2021 = db["crime_record_2021"]
data = collection_2021.find()
df_21=pd.DataFrame.from_dict(data)

# %%
collection_2022 = db["crime_record_2022"]
data = collection_2022.find()
df_22=pd.DataFrame.from_dict(data)

# %%
df_18.head()
# Out:
#                         _id  report_no            reported_date reported_time  \
# 0  63bdfc7ec5f54698ce86ab63  180038631  2018-05-23T00:00:00.000         10:37
# 1  63bdfc7ec5f54698ce86ab61  180039506  2018-05-26T00:00:00.000         01:00
# 2  63bdfc7ec5f54698ce86ab82  180017912  2018-03-08T00:00:00.000         07:59
# 3  63bdfc7ec5f54698ce86abcb  180023774  2018-03-30T00:00:00.000         15:51
# 4  63bdfc7ec5f54698ce86abd8  180027697  2018-04-14T00:00:00.000         03:30
#
#                  from_date from_time                  to_date to_time offense  \
# 0  2018-01-01T00:00:00.000     15:00  2018-05-22T00:00:00.000   16:15     690
# 1  2018-05-26T00:00:00.000     01:00                      NaN     NaN    2655
# 2  2018-02-23T00:00:00.000     17:30  2018-03-08T00:00:00.000   07:00     502
# 3  2018-03-30T00:00:00.000     15:38                      NaN     NaN     630
# 4  2018-04-13T00:00:00.000     23:51                      NaN     NaN     101
#
#   ibrs  ... involvement firearm_used_flag  \
# 0  23H  ...         VIC                 N
# 1  90J  ...         VIC                 N
# 2  220  ...         SUS                 N
# 3  23C  ...         VIC                 N
# 4  09A  ...         SUS                 Y
#
#                                             location race  sex  age  \
# 0  {'human_address': '{"address": "4200 SCOTT RD"...    W    M   74
# 1  {'latitude': '39.09961', 'longitude': '-94.583...    W    M   31
# 2  {'latitude': '39.132702', 'longitude': '-94.50...    U    U  NaN
# 3  {'human_address': '{"address": "8500 STATE LIN...  NaN  NaN  NaN
# 4  {'latitude': '39.001765', 'longitude': '-94.56...    B    M  NaN
#
#   computed_region_kk66_ngf4 computed_region_9t2m_phkm  \
# 0                       NaN                       NaN
# 1                         5                         4
# 2                        53                         4
# 3                       NaN                       NaN
# 4                        96                         2
#
#   computed_region_my34_vmp8 computed_region_w4hf_t6bp
# 0                       NaN                       NaN
# 1                         7                        75
# 2                         7                       144
# 3                       NaN                       NaN
# 4                         7                       151
#
# [5 rows x 29 columns]

# %%
df_19.head()
# Out:
#                         _id   report_no            reported_date  \
# 0  63bdff0ec5f54698ce88a318  KC19027236  2019-04-14T00:00:00.000
# 1  63bdff0ec5f54698ce88a308  KC19044451  2019-06-14T00:00:00.000
# 2  63bdff0ec5f54698ce88a312  KC19033005  2019-05-05T00:00:00.000
# 3  63bdff0ec5f54698ce88a30c  KC19076088  2019-10-04T00:00:00.000
# 4  63bdff0ec5f54698ce88a30d  KC19026328  2019-04-11T00:00:00.000
#
#   reported_time                from_date from_time                  to_date  \
# 0         23:38  2019-04-14T00:00:00.000     23:22                      NaN
# 1         16:34  2019-06-14T00:00:00.000     16:30  2019-06-14T00:00:00.000
# 2         22:57  2019-05-05T00:00:00.000     22:03  2019-05-05T00:00:00.000
# 3         13:59  2019-10-04T00:00:00.000     13:50                      NaN
# 4          9:34  2019-04-11T00:00:00.000     10:03                      NaN
#
#   to_time                        offense ibrs  ... firearm_used_flag race  \
# 0     NaN  City/Municipal Warrant Arrest  NaN  ...             False    W
# 1   16:30            Stealing – Shoplift  23C  ...             False  NaN
# 2   22:40            Stealing – Shoplift  23C  ...             False    B
# 3     NaN          Recovered Stolen Auto  NaN  ...             False  NaN
# 4     NaN  Legacy Incident Report/Arrest  NaN  ...             False    W
#
#    sex  age rep_dist location computed_region_kk66_ngf4  \
# 0    M   19      NaN      NaN                       NaN
# 1  NaN  NaN      NaN      NaN                       NaN
# 2    M   59   PJ3601      NaN                       NaN
# 3  NaN  NaN      NaN      NaN                       NaN
# 4    M   54   PJ1725      NaN                       NaN
#
#   computed_region_9t2m_phkm  computed_region_my34_vmp8  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   computed_region_w4hf_t6bp
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 28 columns]

# %%
df_20.head()
# Out:
#                         _id   report_no            reported_date  \
# 0  63bdff5fc5f54698ce8a386d  KC20007843  2020-01-31T00:00:00.000
# 1  63bdff5fc5f54698ce8a3866  KC20009823  2020-02-07T00:00:00.000
# 2  63bdff5fc5f54698ce8a3868  KC20014727  2020-02-27T00:00:00.000
# 3  63bdff5fc5f54698ce8a3874  KC20014030  2020-02-24T00:00:00.000
# 4  63bdff5fc5f54698ce8a3897  KC20007775  2020-01-31T00:00:00.000
#
#   reported_time                from_date from_time  \
# 0         19:22  2020-01-31T00:00:00.000     15:00
# 1         18:30  2020-02-07T00:00:00.000     18:01
# 2         08:30  2020-01-12T00:00:00.000     16:35
# 3         16:28  2020-02-24T00:00:00.000     16:15
# 4         14:28  2020-01-31T00:00:00.000     14:20
#
#                                 offense ibrs                description beat  \
# 0  Stealing from Auto (Theft from Auto)  23F   Theft From Motor Vehicle  313
# 1                Robbery (Armed Street)  120                    Robbery  542
# 2           Miscellaneous Investigation  NaN                        NaN  344
# 3             Trespass of Real Property  90J  Trespass of Real Property  345
# 4         Possession of Stolen Property  NaN                        NaN  241
#
#    ... firearm_used_flag                  to_date to_time rep_dist  age  \
# 0  ...             False  2020-01-31T00:00:00.000   19:00      NaN   19
# 1  ...              True                      NaN     NaN   PJ6554  NaN
# 2  ...             False                      NaN     NaN   PJ3281   38
# 3  ...             False                      NaN     NaN   PJ3601   26
# 4  ...             False  2020-01-31T00:00:00.000   15:00   PJ5075   22
#
#   location computed_region_kk66_ngf4 computed_region_9t2m_phkm  \
# 0      NaN                       NaN                       NaN
# 1      NaN                       NaN                       NaN
# 2      NaN                       NaN                       NaN
# 3      NaN                       NaN                       NaN
# 4      NaN                       NaN                       NaN
#
#    computed_region_my34_vmp8 computed_region_w4hf_t6bp
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
# [5 rows x 28 columns]

# %%
df_21.head()
# Out:
#                         _id   report_no              report_date report_time  \
# 0  63be049eeb7214537b1a4e94  KC21007968  2021-02-05T01:02:22.000       01:02
# 1  63be049eeb7214537b1a4e83  KC21005420  2021-01-25T11:18:00.000       11:18
# 2  63be049eeb7214537b1a4e82  KC21017210  2021-03-17T15:46:42.000       15:46
# 3  63be049eeb7214537b1a4e9d  KC21013729  2021-03-02T08:43:36.000       08:43
# 4  63be049eeb7214537b1a4e95  KC21010718  2021-02-17T00:06:14.000       00:06
#
#                  from_date from_time                               offense  \
# 0  2021-02-05T01:00:00.000     01:00           Miscellaneous Investigation
# 1  2021-01-25T11:00:00.000     11:00                 Recovered Stolen Auto
# 2  2021-03-17T15:35:00.000     15:35                  Assault (Aggravated)
# 3  2021-03-01T21:30:00.000     21:30  Stealing from Auto (Theft from Auto)
# 4  2021-02-17T00:04:00.000     00:04                                Murder
#
#   ibrs               description beat  ... firearmused_flag  age age_range  \
# 0  NaN                       NaN  544  ...            False   36     35-44
# 1  NaN                       NaN  113  ...            False   20     18-24
# 2  13A        Aggravated Assault  631  ...             True   33     25-34
# 3  23F  Theft From Motor Vehicle  423  ...            False  NaN       NaN
# 4  09A                    Murder  543  ...             True   30     25-34
#
#                    to_date to_time  \
# 0                      NaN     NaN
# 1                      NaN     NaN
# 2                      NaN     NaN
# 3  2021-03-02T06:00:00.000   06:00
# 4                      NaN     NaN
#
#                                             location  \
# 0  {'type': 'Point', 'coordinates': [-94.475406, ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'type': 'Point', 'coordinates': [-94.498365, ...
#
#   :@computed_region_9t2m_phkm :@computed_region_my34_vmp8  \
# 0                           2                           7
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                           1                           7
#
#   :@computed_region_w4hf_t6bp  :@computed_region_kk66_ngf4
# 0                         143                          195
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         143                          190
#
# [5 rows x 29 columns]

# %%
df_22.head()
# Out:
#                         _id   report_no              report_date report_time  \
# 0  63be0519eb7214537b1bb661  KC22000585  2022-01-03T19:09:00.000       19:09
# 1  63be0519eb7214537b1bb677  KC22004485  2022-01-21T21:30:00.000       21:32
# 2  63be0519eb7214537b1bb664  KC22000883  2021-12-27T12:07:00.000       11:18
# 3  63be0519eb7214537b1bb66d  KC22002319  2022-01-11T22:39:00.000       22:39
# 4  63be0519eb7214537b1bb672  KC22003209  2022-01-15T23:01:00.000       23:01
#
#                  from_date from_time                  to_date to_time  \
# 0  2022-01-03T19:09:00.000     19:09  2022-01-03T19:09:00.000     NaN
# 1  2022-01-21T21:30:00.000     21:30  2022-01-21T21:30:00.000     NaN
# 2  2021-12-27T12:07:00.000     12:07  2021-12-27T12:07:00.000   12:09
# 3  2022-01-11T22:39:00.000     22:39  2022-01-11T22:39:00.000     NaN
# 4  2022-01-15T23:01:00.000     23:01  2022-01-15T23:01:00.000     NaN
#
#                              offense ibrs  ... race  sex  age firearmusedflag  \
# 0        Miscellaneous Investigation  NaN  ...    B    F  NaN           False
# 1               Assault (Aggravated)  13A  ...    B    F  NaN            True
# 2                Stealing - Shoplift  23C  ...  NaN  NaN  NaN           False
# 3  Eluding / Resisting a Lawful Stop  NaN  ...    B    M   29           False
# 4                Stealing - Shoplift  23C  ...  NaN  NaN  NaN           False
#
#                                             location age_range  \
# 0  {'type': 'Point', 'coordinates': [-94.57902, 3...       NaN
# 1  {'type': 'Point', 'coordinates': [-94.56952, 3...       NaN
# 2                                                NaN       NaN
# 3  {'type': 'Point', 'coordinates': [-94.57474, 3...     25-34
# 4  {'type': 'Point', 'coordinates': [-94.59069, 3...       NaN
#
#   :@computed_region_kk66_ngf4  :@computed_region_9t2m_phkm  \
# 0                          97                            4
# 1                         205                            2
# 2                         NaN                          NaN
# 3                         235                            4
# 4                          32                            4
#
#   :@computed_region_my34_vmp8 :@computed_region_w4hf_t6bp
# 0                           7                          92
# 1                           7                         163
# 2                         NaN                         NaN
# 3                           7                         165
# 4                           7                          50
#
# [5 rows x 29 columns]

# %%
df_18=df_18.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
df_19=df_19.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
df_20=df_20.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
df_21=df_21.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})
df_22=df_22.rename(columns={":@computed_region_kk66_ngf4": "computed_region_kk66_ngf4", ":@computed_region_9t2m_phkm": "computed_region_9t2m_phkm",":@computed_region_my34_vmp8":"computed_region_my34_vmp8",":@computed_region_w4hf_t6bp":"computed_region_w4hf_t6bp"})

# %%
df_list = [df_18, df_19, df_20,df_21, df_22]
df = pd.concat(df_list, ignore_index=True)
# drop _id column
df.drop('_id', axis=1, inplace=True)

# %%
df_copy=df.copy()

# %% [markdown]
# #### Functions

# %% [markdown]
# #### Data Formating

# %%
df.reported_time= df.reported_time.replace({'24:00':'00:00'}) 
df.from_time= df.from_time.replace({'24:00':'00:00'}) 
df.to_time= df.to_time.replace({'24:00':'00:00'}) 
df.beat=df.beat.fillna(np.nan)

# %% [markdown]
# #### Specifying Categorical and Numerical Columns

# %%
df.columns
# Out:
# Index(['report_no', 'reported_date', 'reported_time', 'from_date', 'from_time',
#        'to_date', 'to_time', 'offense', 'ibrs', 'description', 'beat',
#        'address', 'city', 'zip_code', 'rep_dist', 'area', 'dvflag', 'invl_no',
#        'involvement', 'firearm_used_flag', 'location', 'race', 'sex', 'age',
#        'computed_region_kk66_ngf4', 'computed_region_9t2m_phkm',
#        'computed_region_my34_vmp8', 'computed_region_w4hf_t6bp', 'report_date',
#        'report_time', 'firearmused_flag', 'age_range', 'firearmusedflag'],
#       dtype='object')

# %%
date_cols=['reported_date', 'reported_time', 'from_date','from_time', 'to_date', 'to_time']
cat_cols=['offense', 'ibrs', 'beat', 'zip_code', 'rep_dist', 'area','dvflag','invl_no','involvement','race','sex','computed_region_kk66_ngf4','computed_region_9t2m_phkm','computed_region_my34_vmp8','computed_region_w4hf_t6bp']
num_cols=['report_no','age']

# %%
for i in df.columns:
    if (i in date_cols) or (i in cat_cols) or (i in num_cols) :
        pass
    else:
        print("*****",i)
# Out:
# ***** description
# ***** address
# ***** city
# ***** firearm_used_flag
# ***** location
# ***** report_date
# ***** report_time
# ***** firearmused_flag
# ***** age_range
# ***** firearmusedflag

# %% [markdown]
# #### Assign appropriate datatype

# %%
df.reported_time=df.reported_time.astype(str)

# %%
#df.report_no=df.report_no.astype(int)
df.reported_date=pd.to_datetime(df.reported_date)
df.reported_time = pd.to_datetime(df.reported_time, format='%H:%M').dt.time
#df.from_date=pd.to_datetime(df.from_date)
#df.from_time = pd.to_datetime(df.from_time, format='%H:%M').dt.time
#df.to_date=pd.to_datetime(df.to_date)
#df.to_time = pd.to_datetime(df.to_time, format='%H:%M').dt.time
#df.offense=df.offense.astype(int)
#df.beat=df.beat.astype(float)
#df.invl_no=df.invl_no.astype(float)
#df.age=df.age.astype(float)
#df.computed_region_kk66_ngf4=df.computed_region_kk66_ngf4.astype(float)
#df.computed_region_kk66_ngf4=df.computed_region_kk66_ngf4.astype(float)
#df.computed_region_kk66_ngf4=df.computed_region_kk66_ngf4.astype(float)
#df.computed_region_kk66_ngf4=df.computed_region_kk66_ngf4.astype(float)

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520804 entries, 0 to 520803
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   report_no                  520804 non-null  object
#  1   reported_date              328930 non-null  datetime64[ns]
#  2   reported_time              520804 non-null  object
#  3   from_date                  520462 non-null  object
#  4   from_time                  520323 non-null  object
#  5   to_date                    250710 non-null  object
#  6   to_time                    183909 non-null  object
#  7   offense                    520804 non-null  object
#  8   ibrs                       477025 non-null  object
#  9   description                452665 non-null  object
#  10  beat                       517580 non-null  object
#  11  address                    520758 non-null  object
#  12  city                       520726 non-null  object
#  13  zip_code                   483828 non-null  object
#  14  rep_dist                   430810 non-null  object
#  15  area                       516794 non-null  object
#  16  dvflag                     520804 non-null  object
#  17  invl_no                    128938 non-null  float64
#  18  involvement                520804 non-null  object
#  19  firearm_used_flag          328930 non-null  object
#  20  location                   452622 non-null  object
#  21  race                       450876 non-null  object
#  22  sex                        455908 non-null  object
#  23  age                        359381 non-null  object
#  24  computed_region_kk66_ngf4  407270 non-null  object
#  25  computed_region_9t2m_phkm  407270 non-null  object
#  26  computed_region_my34_vmp8  416092 non-null  object
#  27  computed_region_w4hf_t6bp  416092 non-null  object
#  28  report_date                191873 non-null  object
#  29  report_time                191874 non-null  object
#  30  firearmused_flag           92127 non-null   object
#  31  age_range                  141798 non-null  object
#  32  firearmusedflag            99747 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(31)
# memory usage: 131.1+ MB

# %%
df_18.dtypes.to_frame()
# Out:
#                                         0
# _id                                object
# report_no                           int32
# reported_date              datetime64[ns]
# reported_time                      object
# from_date                  datetime64[ns]
# from_time                          object
# to_date                    datetime64[ns]
# to_time                            object
# offense                             int32
# ibrs                               object
# description                        object
# beat                              float64
# address                            object
# city                               object
# zip_code                           object
# rep_dist                           object
# area                               object
# dvflag                             object
# invl_no                           float64
# involvement                        object
# firearm_used_flag                  object
# location                           object
# race                               object
# sex                                object
# age                               float64
# computed_region_kk66_ngf4          object
# computed_region_9t2m_phkm          object
# computed_region_my34_vmp8          object
# computed_region_w4hf_t6bp          object

# %% [markdown]
# #### Descriptive Data Analysis

# %%
df.describe().T
# Out:
#               count          mean            std         min          25%  \
# report_no  128938.0  1.800333e+08  755286.315434  50026148.0  180026000.0
# offense    128938.0  1.006383e+03     649.285439       101.0        640.0
# beat       127514.0  3.231242e+02     196.954451         5.0        144.0
# invl_no    128938.0  1.262452e+00       1.266882         1.0          1.0
# age         70043.0  3.768515e+01      15.157687        18.0         26.0
#
#                    50%          75%          max
# report_no  180050470.5  180075170.0  189936611.0
# offense          702.0       1401.0       3079.0
# beat             314.0        421.0       9999.0
# invl_no            1.0          1.0         57.0
# age               34.0         47.0        506.0

# %% [markdown]
# #### Detecting and Plotting NaN values

# %%
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)

    x = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return x[x['Percent'] > 0]

# %%
missing_data(df)
# Out:
#                            Total    Percent
# to_time                    79592  61.728893
# to_date                    79126  61.367479
# age                        58895  45.676992
# computed_region_9t2m_phkm  37186  28.840218
# computed_region_kk66_ngf4  37186  28.840218
# computed_region_w4hf_t6bp  35965  27.893251
# computed_region_my34_vmp8  35965  27.893251
# sex                        18203  14.117638
# race                       18203  14.117638
# beat                        1424   1.104407
# area                        1311   1.016768
# rep_dist                    1311   1.016768
# ibrs                        1141   0.884921
# from_time                    385   0.298593
# from_date                    266   0.206301
# city                          37   0.028696
# address                       27   0.020940

# %%
#pip install missingno
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plotting Numerical Columns

# %%
df.boxplot(column='age')
# Out:
# <AxesSubplot:>

# %%
df['age'][df['age']>100]
# Out:
# 305       152.0
# 2060      242.0
# 21797     103.0
# 23305     401.0
# 26088     133.0
# 27701     203.0
# 31207     101.0
# 32101     201.0
# 32660     201.0
# 33172     201.0
# 34253     202.0
# 34380     120.0
# 36400     141.0
# 36596     152.0
# 41982     114.0
# 51962     351.0
# 65254     202.0
# 68646     501.0
# 71889     303.0
# 90678     203.0
# 105865    335.0
# 105882    141.0
# 108881    202.0
# 111179    506.0
# 111841    506.0
# 113634    202.0
# 115262    201.0
# 123231    201.0
# Name: age, dtype: float64

# %%
df['age'][df['age']<100].mean().round()
# Out:
# 38.0

# %%
df['age'][df['age']>100]=38

# %%
df['age'].hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plotting Categorical Columns
